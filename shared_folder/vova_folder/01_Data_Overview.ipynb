# %% [markdown]
# <div style="
#   padding: 18px 24px;
#   margin-top: 15px;
#   margin-bottom: 25px;
#   border-left: 6px solid var(--jp-info-color0);
#   background: var(--jp-layout-color2);
#   border-radius: 8px;
# ">
# <h1 style="margin:0; color:var(--jp-ui-font-color1);">
# 01. Data Overview
# </h1>
# <p style="font-size: 1.1em; color: var(--jp-ui-font-color1); margin-top: 6px;">
# Описание датасета
# </p>
# </div>

# %% [markdown]
# <h2 style="
#   padding: 6px 0;
#   border-bottom: 2px solid var(--jp-border-color2);
#   /* color: var(--jp-ui-font-color1); */
#   margin-top: 32px;
# ">
# 01.1 Kaggle
# </h2>
#
#
# Датасет размещен на Kaggle - <a href="https://www.kaggle.com/competitions/playground-series-s4e2/data" style="text-decoration: underline;">Multi-Class Prediction of Obesity Risk</a>
#
# **Там же дано его описание:**
#
# Набор данных для этого соревнования (как тренировки, так и теста) был создан из модели глубокого обучения, обученной на наборе данных о рисках ожирения или сердечно-сосудистых заболеваний. Распределение функций близко, но не совсем такое же, как оригинал. Не стесняйтесь использовать оригинальный набор данных в рамках этого конкурса, как для изучения различий, так и для того, чтобы увидеть, улучшает ли включение оригинала в обучение производительность модели.
#
# Ссылка на оригинальный датасет, на котором сделан текущий - <a href="https://www.kaggle.com/datasets/aravindpcoder/obesity-or-cvd-risk-classifyregressorcluster" style="text-decoration: underline;">Obesity or CVD risk (Classify/Regressor/Cluster)</a>
#
# Данные состоят из оценки уровня ожирения у людей из стран Мексики, Перу и Колумбии, в возрасте от 14 до 61 года, с различными привычками питания и физическим состоянием, данные были собраны с помощью веб-платформы с опросом, в котором анонимные пользователи ответили на каждый вопрос, затем информация была обработана, получены 17 атрибутов и 2111 записей.
#
# Атрибуты, связанные с пищевыми привычками:
# - частое потребление высококалорийной пищи (FAVC),
# - частота потребления овощей (FCVC),
# - количество основных приемов пищи (NCP),
# - потребление пищи между приемами пищи (CAEC),
# - ежедневное потребление воды (CH20) и
# - потребление алкоголя (CALC).
#
# Атрибуты, связанные с физическим состоянием:
# - мониторинг потребления калорий (SCC),
# - частота физической активности (FAF),
# - время с использованием технологических устройств (TUE),
# - используемый транспорт (MTRANS).
#
# Параметры опрашиваемых:
# - пол,
# - возраст,
# - рост и
# - вес.
#
# Значения NObesity:
# - Недостаточным весом менее 18,5
# - Обыкновые с 18,5 до 24,9
# - Чрезмерный вес от 25,0 до 29,9
# - Ожирение I от 30,0 до 34,9
# - Ожирение II от 35,0 до 39,9
# - Ожирение III выше 40

# %% [markdown]
# <h2 style="
#   padding: 6px 0;
#   border-bottom: 2px solid var(--jp-border-color2);
#   /* color: var(--jp-ui-font-color1); */
#   margin-top: 32px;
# ">
# 01.2 Оригинальная статья
# </h2>
#
# Оригинальная статья с исследованием:
#
# <a href="https://www.sciencedirect.com/science/article/pii/S2352340919306985" style="text-decoration: underline;">Dataset for estimation of obesity levels based on eating habits and physical condition in individuals from Colombia, Peru and Mexico</a>
#
# В этой статье есть дополнительное описание датасета: 77% данных было сгенерировано синтетически с использованием инструмента Weka и фильтра SMOTE, 23% данных были собраны непосредственно от пользователей через веб-платформу.
#
# Также представлена оригинальная анкета, которая использовалась в опросе, это дает понимание сутевой составляющей датасета.
#
# 1) Какой у тебя пол?
# - Женщина
# - Мужчина
#
# 2) Сколько тебе лет?
# - Числовое значение
#
# 3) Какой у тебя рост?
# - Числовое значение в метрах
#
# 4) Какой у тебя вес?
# - Числовое значение в килограммах
#
# 5) Страдал ли член семьи или страдает от избыточного веса?
# - Да
# - Нет
#
# 6) Вы часто едите высококалорийную пищу?
# - Да
# - Нет
#
# 7) Вы обычно едите овощи во время еды?
# - Никогда
# - Иногда
# - Всегда
#
# 8) Сколько основных приемов пищи вы ем в день?
# - Между 1 и 2
# - Три
# - Больше трех
#
# 9) Ты ешь что-нибудь между приемами пищи?
# - Нет
# - Иногда
# - Часто
# - Всегда
#
# 10) Ты куришь?
# - Да
# - Нет
#
# 11) Сколько воды вы пьете в день?
# - Меньше литра
# - От 1 до 2 л
# - Более 2 л
#
# 12) Вы контролируете количество калорий, которые вы едите каждый день?
# - Да
# - Нет
#
# 13) Как часто вы занимаетесь физической активностью?
# - Никогда
# - 1 или 2 дня
# - 2 или 4 дня
# - 4 или 5 дней
#
# 14) Сколько времени вы используете технологические устройства, такие как мобильный телефон, видеоигры, телевизор, компьютер и другие?
# - 0–2 часа
# - 3-5 часов
# - Более 5 часов
#
# 15) Как часто ты пьешь алкоголь?
# - Я не пью
# - Иногда
# - Часто
# - Всегда
#
# 16) Каким транспортом вы обычно пользуетесь?
# - Автомобиль
# - Мотоцикл
# - Мотоцикл
# - Общественный Транспорт
# - Ходьба
